# %% [markdown]
# this file draws plots for SPDEF TF

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import matplotlib
import os, sys

# %%
overlap_folder = '/stg3/data3/peiyao/work/20230922.Lina_lung/results/chipseq/overlap_results'

# %%
# draw feature plots for SPDEF and its regulatees
# part 1 visualize data

# 'H3K4me3', H3K27ac', 'H3K27me3', 'H3K4me1', 'H3K9me3'
feature = 'H3K9me3'
overlap_result = pd.read_csv(os.path.join('/stg3/data3/peiyao/work/20230922.Lina_lung/results/chipseq/overlap_results', 'overlap.{}.txt'.format(feature)), sep='\t', header=None, )
overlap_result = overlap_result[overlap_result[10]!=0]
overlap_result
# Out:
#         0         1         2                   3      4         5         6   \
# 94   chr15  68346517  68480402  PIAS1.transcript_0  chr15  68389106  68389506
# 95   chr15  68346517  68480402  PIAS1.transcript_0  chr15  68413343  68413743
# 96   chr15  68346647  68434677  PIAS1.transcript_1  chr15  68389106  68389506
# 97   chr15  68346647  68434677  PIAS1.transcript_1  chr15  68413343  68413743
# 98   chr15  68346656  68434677  PIAS1.transcript_2  chr15  68389106  68389506
# 99   chr15  68346656  68434677  PIAS1.transcript_2  chr15  68413343  68413743
# 100  chr15  68346914  68480402  PIAS1.transcript_3  chr15  68389106  68389506
# 101  chr15  68346914  68480402  PIAS1.transcript_3  chr15  68413343  68413743
#
#                         7                  8                   9    10
# 94    pk_8129.cancerhigh_0  0.307558307369172  0.0172773539903902  400
# 95   pk_10260.cancerhigh_0  0.315834269679106   0.023028644179123  400
# ...
